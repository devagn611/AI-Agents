# %%
import getpass
import os


def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"Please provide your {var}")


# _set_if_undefined("ANTHROPIC_API_KEY")
_set_if_undefined("TAVILY_API_KEY")

# %%
# %pip install langchain_experimental
# Out:
# Requirement already satisfied: langchain_experimental in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain_experimental) (0.3.20)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.28 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain_experimental) (0.3.49)
# Requirement already satisfied: langchain<1.0.0,>=0.3.21 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.22)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.19)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (4.13.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (2.11.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.21->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.7)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.1.1)
# Requirement already satisfied: anyio in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.1)
# Requirement already satisfied: exceptiongroup in /home/dev/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import Annotated

from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.tools import tool
from langchain_experimental.utilities import PythonREPL

tavily_tool = TavilySearchResults(max_results=5)

# Warning: This executes code locally, which can be unsafe when not sandboxed

repl = PythonREPL()


@tool
def python_repl_tool(
    code: Annotated[str, "The python code to execute to generate your chart."],
):
    """Use this to execute python code. If you want to see the output of a value,
    you should print it out with `print(...)`. This is visible to the user."""
    try:
        result = repl.run(code)
    except BaseException as e:
        return f"Failed to execute. Error: {repr(e)}"
    result_str = f"Successfully executed:\n\`\`\`python\n{code}\n\`\`\`\nStdout: {result}"
    return (
        result_str + "\n\nIf you have completed all tasks, respond with FINAL ANSWER."
    )

# %%
def make_system_prompt(suffix: str) -> str:
    return (
        "You are a helpful AI assistant, collaborating with other assistants."
        " Use the provided tools to progress towards answering the question."
        " If you are unable to fully answer, that's OK, another assistant with different tools "
        " will help where you left off. Execute what you can to make progress."
        " If you or any of the other assistants have the final answer or deliverable,"
        " prefix your response with FINAL ANSWER so the team knows to stop."
        f"\n{suffix}"
    )

# %%
from typing import Literal

from langchain_core.messages import BaseMessage, HumanMessage
# from langchain_anthropic import ChatAnthropic
from langgraph.prebuilt import create_react_agent
from langgraph.graph import MessagesState, END
from langgraph.types import Command
from langchain_groq import ChatGroq


GROQ_API_KEY=os.getenv("GROQ_API_KEY")
os.environ["GROQ_API_KEY"]= GROQ_API_KEY

# llm = ChatAnthropic(model="claude-3-5-sonnet-latest")
llm=ChatGroq(model="llama3-70b-8192")


def get_next_node(last_message: BaseMessage, goto: str):
    if "FINAL ANSWER" in last_message.content:
        # Any agent decided the work is done
        return END
    return goto


# Research agent and node
research_agent = create_react_agent(
    llm,
    tools=[tavily_tool],
    prompt=make_system_prompt(
        "You can only do research. You are working with a chart generator colleague."
    ),
)


def research_node(
    state: MessagesState,
) -> Command[Literal["chart_generator", END]]:
    messages= state["messages"]
    result = research_agent.invoke(messages)
    print("----Result----", result)
    goto = get_next_node(result["messages"][-1], "chart_generator")
    # wrap in a human message, as not all providers allow
    # AI message at the last position of the input messages list
    result["messages"][-1] = HumanMessage(
        content=result["messages"][-1].content, name="researcher"
    )
    return Command(
        update={
            # share internal message history of research agent with other agents
            "messages": result["messages"],
        },
        goto=goto,
    )


# Chart generator agent and node
# NOTE: THIS PERFORMS ARBITRARY CODE EXECUTION, WHICH CAN BE UNSAFE WHEN NOT SANDBOXED
chart_agent = create_react_agent(
    llm,
    [python_repl_tool],
    prompt=make_system_prompt(
        "You can only generate charts. You are working with a researcher colleague."
    ),
)


def chart_node(state: MessagesState) -> Command[Literal["researcher", END]]:
    result = chart_agent.invoke(state)
    print("----Result----", result)

    goto = get_next_node(result["messages"][-1], "researcher")
    print("----Goto----", goto)
    # wrap in a human message, as not all providers allow
    # AI message at the last position of the input messages list
    result["messages"][-1] = HumanMessage(
        content=result["messages"][-1].content, name="chart_generator"
    )
    return Command(
        update={
            # share internal message history of chart agent with other agents
            "messages": result["messages"],
        },
        goto=goto,
    )

# %%
from langgraph.graph import StateGraph, START

workflow = StateGraph(MessagesState)
workflow.add_node("researcher", research_node)
workflow.add_node("chart_generator", chart_node)

workflow.add_edge(START, "researcher")
graph = workflow.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
events = graph.stream(
    {
        "messages": [
            (
                "user",
                "First, get the UK's GDP over the past 5 years, then make a line chart of it. "
                "Once you make the chart, finish.",
            )
        ],
    },
    # Maximum number of steps to take in the graph
    {"recursion_limit": 150},
)
for s in events:
    print(s)
    print("----")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[27], line 14
#       1 events = graph.stream(
#       2     {
#       3         "messages": [
#    (...)
#      12     {"recursion_limit": 150},
#      13 )
# ---> 14 for s in events:
#      15     print(s)
#      16     print("----")
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2340, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2334     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2335     # computation proceeds in steps, while there are channel updates.
#    2336     # Channel updates from step N are only visible in step N+1
#    2337     # channels are guaranteed to be immutable for the duration of the step,
#    2338     # with channel updates applied only at the transition between steps.
#    2339     while loop.tick(input_keys=self.input_channels):
# -> 2340         for _ in runner.tick(
#    2341             loop.tasks.values(),
#    2342             timeout=self.step_timeout,
#    2343             retry_policy=self.retry_policy,
#    2344             get_waiter=get_waiter,
#    2345         ):
#    2346             # emit output
#    2347             yield from output()
#    2348 # emit output
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/pregel/runner.py:158, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     156 t = tasks[0]
#     157 try:
# --> 158     run_with_retry(
#     159         t,
#     160         retry_policy,
#     161         configurable={
#     162             CONFIG_KEY_CALL: partial(
#     163                 _call,
#     164                 weakref.ref(t),
#     165                 retry=retry_policy,
#     166                 futures=weakref.ref(futures),
#     167                 schedule_task=self.schedule_task,
#     168                 submit=self.submit,
#     169                 reraise=reraise,
#     170             ),
#     171         },
#     172     )
#     173     self.commit(t, None)
#     174 except Exception as exc:
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/utils/runnable.py:606, in RunnableSeq.invoke(self, input, config, **kwargs)
#     602 config = patch_config(
#     603     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     604 )
#     605 if i == 0:
# --> 606     input = step.invoke(input, config, **kwargs)
#     607 else:
#     608     input = step.invoke(input, config)
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/utils/runnable.py:371, in RunnableCallable.invoke(self, input, config, **kwargs)
#     369 else:
#     370     with set_config_context(config) as context:
# --> 371         ret = context.run(self.func, *args, **kwargs)
#     372 if isinstance(ret, Runnable) and self.recurse:
#     373     return ret.invoke(input, config)
#
# Cell In[8], line 38, in research_node(state)
#      35 def research_node(
#      36     state: MessagesState,
#      37 ) -> Command[Literal["chart_generator", END]]:
# ---> 38     result = research_agent.invoke(state)
#      39     goto = get_next_node(result["messages"][-1], "chart_generator")
#      40     # wrap in a human message, as not all providers allow
#      41     # AI message at the last position of the input messages list
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2688, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2686 else:
#    2687     chunks = []
# -> 2688 for chunk in self.stream(
#    2689     input,
#    2690     config,
#    2691     stream_mode=stream_mode,
#    2692     output_keys=output_keys,
#    2693     interrupt_before=interrupt_before,
#    2694     interrupt_after=interrupt_after,
#    2695     debug=debug,
#    2696     **kwargs,
#    2697 ):
#    2698     if stream_mode == "values":
#    2699         latest = chunk
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/pregel/__init__.py:2340, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2334     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2335     # computation proceeds in steps, while there are channel updates.
#    2336     # Channel updates from step N are only visible in step N+1
#    2337     # channels are guaranteed to be immutable for the duration of the step,
#    2338     # with channel updates applied only at the transition between steps.
#    2339     while loop.tick(input_keys=self.input_channels):
# -> 2340         for _ in runner.tick(
#    2341             loop.tasks.values(),
#    2342             timeout=self.step_timeout,
#    2343             retry_policy=self.retry_policy,
#    2344             get_waiter=get_waiter,
#    2345         ):
#    2346             # emit output
#    2347             yield from output()
#    2348 # emit output
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/pregel/runner.py:158, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     156 t = tasks[0]
#     157 try:
# --> 158     run_with_retry(
#     159         t,
#     160         retry_policy,
#     161         configurable={
#     162             CONFIG_KEY_CALL: partial(
#     163                 _call,
#     164                 weakref.ref(t),
#     165                 retry=retry_policy,
#     166                 futures=weakref.ref(futures),
#     167                 schedule_task=self.schedule_task,
#     168                 submit=self.submit,
#     169                 reraise=reraise,
#     170             ),
#     171         },
#     172     )
#     173     self.commit(t, None)
#     174 except Exception as exc:
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/utils/runnable.py:606, in RunnableSeq.invoke(self, input, config, **kwargs)
#     602 config = patch_config(
#     603     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     604 )
#     605 if i == 0:
# --> 606     input = step.invoke(input, config, **kwargs)
#     607 else:
#     608     input = step.invoke(input, config)
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/utils/runnable.py:363, in RunnableCallable.invoke(self, input, config, **kwargs)
#     361     child_config = patch_config(config, callbacks=run_manager.get_child())
#     362     with set_config_context(child_config) as context:
# --> 363         ret = context.run(self.func, *args, **kwargs)
#     364 except BaseException as e:
#     365     run_manager.on_chain_error(e)
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langgraph/prebuilt/chat_agent_executor.py:745, in create_react_agent.<locals>.call_model(state, config)
#     743 def call_model(state: StateSchema, config: RunnableConfig) -> StateSchema:
#     744     state = _get_model_input_state(state)
# --> 745     response = cast(AIMessage, model_runnable.invoke(state, config))
#     746     # add agent name to the AIMessage
#     747     response.name = name
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langchain_core/runnables/base.py:3025, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3023                 input = context.run(step.invoke, input, config, **kwargs)
#    3024             else:
# -> 3025                 input = context.run(step.invoke, input, config)
#    3026 # finish the root run
#    3027 except BaseException as e:
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langchain_core/runnables/base.py:5358, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5352 def invoke(
#    5353     self,
#    5354     input: Input,
#    5355     config: Optional[RunnableConfig] = None,
#    5356     **kwargs: Optional[Any],
#    5357 ) -> Output:
# -> 5358     return self.bound.invoke(
#    5359         input,
#    5360         self._merge_configs(config),
#    5361         **{**self.kwargs, **kwargs},
#    5362     )
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:307, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     296 def invoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)
#     302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
#     305     return cast(
#     306         ChatGeneration,
# --> 307         self.generate_prompt(
#     308             [self._convert_input(input)],
#     309             stop=stop,
#     310             callbacks=config.get("callbacks"),
#     311             tags=config.get("tags"),
#     312             metadata=config.get("metadata"),
#     313             run_name=config.get("run_name"),
#     314             run_id=config.pop("run_id", None),
#     315             **kwargs,
#     316         ).generations[0][0],
#     317     ).message
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:843, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     835 def generate_prompt(
#     836     self,
#     837     prompts: list[PromptValue],
#    (...)
#     840     **kwargs: Any,
#     841 ) -> LLMResult:
#     842     prompt_messages = [p.to_messages() for p in prompts]
# --> 843     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:683, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 for i, m in enumerate(messages):
#     681     try:
#     682         results.append(
# --> 683             self._generate_with_cache(
#     684                 m,
#     685                 stop=stop,
#     686                 run_manager=run_managers[i] if run_managers else None,
#     687                 **kwargs,
#     688             )
#     689         )
#     690     except BaseException as e:
#     691         if run_managers:
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:908, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906 else:
#     907     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908         result = self._generate(
#     909             messages, stop=stop, run_manager=run_manager, **kwargs
#     910         )
#     911     else:
#     912         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/langchain_groq/chat_models.py:498, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     493 message_dicts, params = self._create_message_dicts(messages, stop)
#     494 params = {
#     495     **params,
#     496     **kwargs,
#     497 }
# --> 498 response = self.client.create(messages=message_dicts, **params)
#     499 return self._create_chat_result(response)
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/groq/resources/chat/completions.py:322, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, reasoning_format, response_format, seed, service_tier, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     166 def create(
#     167     self,
#     168     *,
#    (...)
#     198     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     199 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     200     """
#     201     Creates a model response for the given chat conversation.
#     202
#    (...)
#     320       timeout: Override the client-level default timeout for this request, in seconds
#     321     """
# --> 322     return self._post(
#     323         "/openai/v1/chat/completions",
#     324         body=maybe_transform(
#     325             {
#     326                 "messages": messages,
#     327                 "model": model,
#     328                 "frequency_penalty": frequency_penalty,
#     329                 "function_call": function_call,
#     330                 "functions": functions,
#     331                 "logit_bias": logit_bias,
#     332                 "logprobs": logprobs,
#     333                 "max_completion_tokens": max_completion_tokens,
#     334                 "max_tokens": max_tokens,
#     335                 "n": n,
#     336                 "parallel_tool_calls": parallel_tool_calls,
#     337                 "presence_penalty": presence_penalty,
#     338                 "reasoning_format": reasoning_format,
#     339                 "response_format": response_format,
#     340                 "seed": seed,
#     341                 "service_tier": service_tier,
#     342                 "stop": stop,
#     343                 "stream": stream,
#     344                 "temperature": temperature,
#     345                 "tool_choice": tool_choice,
#     346                 "tools": tools,
#     347                 "top_logprobs": top_logprobs,
#     348                 "top_p": top_p,
#     349                 "user": user,
#     350             },
#     351             completion_create_params.CompletionCreateParams,
#     352         ),
#     353         options=make_request_options(
#     354             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     355         ),
#     356         cast_to=ChatCompletion,
#     357         stream=stream or False,
#     358         stream_cls=Stream[ChatCompletionChunk],
#     359     )
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/groq/_base_client.py:917, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914 else:
#     915     retries_taken = 0
# --> 917 return self._request(
#     918     cast_to=cast_to,
#     919     options=options,
#     920     stream=stream,
#     921     stream_cls=stream_cls,
#     922     retries_taken=retries_taken,
#     923 )
#
# File ~/Desktop/Learning/AI/graph_yt/env/lib/python3.10/site-packages/groq/_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1028     retries_taken=retries_taken,
#    1029 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>{"tool_calls":[{"id": "make_chart","type": "function","function":{"name": "chart_generator"},"parameters":{"data": {"2020": -10.36,"2021": 8.67,"2022": 4.35,"2023": 0.10,"2024": 0.90},"title": "UK GDP","x_axis": "Year","y_axis": "GDP Growth Rate"}}]}</tool-use>'}}

# %%
for s in events:
    print(s)
    print("----")
